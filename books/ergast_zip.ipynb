# %% [markdown]
# # ErgastZIP
#
# Extract, transform, and load from an
# https://ergast.com/mrd/db database image.

# %%
# %autosave 0
from tools import ERGAST_ZIP, ErgastZIP, afew
# Out:
# Autosave disabled

# %%
f1 = ErgastZIP(ERGAST_ZIP)
f1.tables
# Out:
# ['circuits.csv',
#  'constructor_results.csv',
#  'constructors.csv',
#  'constructor_standings.csv',
#  'driver.csv',
#  'driver_standings.csv',
#  'lap_times.csv',
#  'pit_stops.csv',
#  'qualifying.csv',
#  'races.csv',
#  'results.csv',
#  'seasons.csv',
#  'status.csv']

# %% [markdown]
# ## Series

# %%
f1.seasons.head()
# Out:
# 0    2009
# 1    2008
# 2    2007
# 3    2006
# 4    2005
# Name: year, dtype: int64

# %%
f1.status.head()
# Out:
# 1        Finished
# 2    Disqualified
# 3        Accident
# 4       Collision
# 5          Engine
# Name: status, dtype: object

# %% [markdown]
# ## DataFrames

# %%
def show(data):
    print(data.info())
    return afew(data)

# %%
show(f1.circuits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 1 to 74
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   circuit    74 non-null     object
#  1   city       74 non-null     object
#  2   country    74 non-null     object
#  3   latitude   74 non-null     float64
#  4   longitude  74 non-null     float64
#  5   ref        74 non-null     object
#  6   url        74 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.6+ KB
# None
#                    circuit          city       country  latitude  longitude  \
# 34     Circuit Paul Ricard  Le Castellet        France   43.2506    5.79167
# 50        Nivelles-Baulers      Brussels       Belgium   50.6211    4.32694
# 16           Fuji Speedway         Oyama         Japan   35.3717  138.92700
# 30                 Kyalami       Midrand  South Africa  -25.9894   28.07670
# 52  Circuit Mont-Tremblant        Quebec        Canada   46.1877  -74.60990
#
#           ref                                                url
# 34     ricard   http://en.wikipedia.org/wiki/Paul_Ricard_Circuit
# 50   nivelles      http://en.wikipedia.org/wiki/Nivelles-Baulers
# 16       fuji         http://en.wikipedia.org/wiki/Fuji_Speedway
# 30    kyalami               http://en.wikipedia.org/wiki/Kyalami
# 52  tremblant  http://en.wikipedia.org/wiki/Circuit_Mont-Trem...

# %%
show(f1.drivers)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847 entries, 1 to 848
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birthday  847 non-null    datetime64[ns]
#  1   code      90 non-null     object
#  2   driver    847 non-null    object
#  3   nation    847 non-null    object
#  4   number    847 non-null    int64
#  5   ref       847 non-null    object
#  6   url       846 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 52.9+ KB
# None
#       birthday code         driver      nation  number      ref  \
# 534 1916-06-15  NaN     Gene Force    American       0    force
# 17  1976-08-27  WEB    Mark Webber  Australian       0   webber
# 479 1932-02-25  NaN    Tony Brooks     British       0   brooks
# 361 1942-05-27  NaN  Piers Courage     British       0  courage
# 147 1961-04-20  NaN  Paolo Barilla     Italian       0  barilla
#
#                                             url
# 534     http://en.wikipedia.org/wiki/Gene_Force
# 17     http://en.wikipedia.org/wiki/Mark_Webber
# 479    http://en.wikipedia.org/wiki/Tony_Brooks
# 361  http://en.wikipedia.org/wiki/Piers_Courage
# 147  http://en.wikipedia.org/wiki/Paolo_Barilla

# %%
show(f1.driver_standings)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32566 entries, 1 to 69748
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_driver  32566 non-null  int64
#  1   id_race    32566 non-null  int64
#  2   points     32566 non-null  float64
#  3   pos        32566 non-null  int64
#  4   wins       32566 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 1.5 MB
# None
#        id_driver  id_race  points  pos  wins
# 50803        356      712     8.0    6     0
# 65379        819      874     0.0   23     0
# 53489        235      642    19.0    4     1
# 43271        747      835     0.0   48     0
# 18430         55      362     3.0   17     0

# %%
show(f1.lap_times)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472504 entries, 0 to 472503
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id_driver  472504 non-null  int64
#  1   id_race    472504 non-null  int64
#  2   lap        472504 non-null  int64
#  3   pos        472504 non-null  int64
#  4   seconds    472504 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 18.0 MB
# None
#         id_driver  id_race  lap  pos  seconds
# 62177           8      891   10    7  115.984
# 154813         22      199   26   16  105.508
# 102841        822      937    6    6  117.702
# 298502         21       66   27    7   88.800
# 14179           5      851   47   17   91.116

# %%
show(f1.pit_stops)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7436 entries, 0 to 7435
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   duration   7436 non-null   float64
#  1   id_driver  7436 non-null   int64
#  2   id_race    7436 non-null   int64
#  3   lap        7436 non-null   int64
#  4   stop       7436 non-null   int64
#  5   time       7436 non-null   timedelta64[ns]
# dtypes: float64(1), int64(4), timedelta64[ns](1)
# memory usage: 348.7 KB
# None
#       duration  id_driver  id_race  lap  stop     time
# 4984    22.707        831      956   43     3 14:58:35
# 4574    21.531          3      948   12     1 16:25:48
# 833     30.544         22      854   30     2 21:04:10
# 7171    39.046          8     1022    1     1 15:16:10
# 2995    22.397        815      899   44     2 15:01:41

# %%
show(f1.qualifying)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8354 entries, 1 to 8377
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_driver  8354 non-null   int64
#  1   id_race    8354 non-null   int64
#  2   id_team    8354 non-null   int64
#  3   number     8354 non-null   int64
#  4   pos        8354 non-null   int64
#  5   q1         8220 non-null   float64
#  6   q2         4260 non-null   float64
#  7   q3         2584 non-null   float64
# dtypes: float64(3), int64(5)
# memory usage: 587.4 KB
# None
#       id_driver  id_race  id_team  number  pos       q1       q2       q3
# 738          11       52        8      22   18   74.098      NaN      NaN
# 5157         17      868        9       2    2  107.276  115.898  111.793
# 4004         31      120        3       3    4   82.180      NaN      NaN
# 2704         14      262        3       2    5   87.211      NaN      NaN
# 5230        813      871        3      18    3  108.993  108.780  107.893

# %%
show(f1.races)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1040 entries, 1 to 1052
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1040 non-null   datetime64[ns]
#  1   id_circuit  1040 non-null   int64
#  2   race        1040 non-null   object
#  3   round       1040 non-null   int64
#  4   season      1040 non-null   int64
#  5   time        308 non-null    timedelta64[ns]
#  6   url         1040 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(2), timedelta64[ns](1)
# memory usage: 65.0+ KB
# None
#            date  id_circuit                      race  round  season     time  \
# 642  1971-10-03          46  United States Grand Prix     11    1971      NaT
# 673  1968-07-20          38        British Grand Prix      7    1968      NaT
# 918  2014-11-23          24      Abu Dhabi Grand Prix     19    2014 13:00:00
# 582  1975-06-08          47        Swedish Grand Prix      7    1975      NaT
# 1002 2018-09-02          14        Italian Grand Prix     14    2018 13:10:00
#
#                                                     url
# 642   http://en.wikipedia.org/wiki/1971_United_State...
# 673   http://en.wikipedia.org/wiki/1968_British_Gran...
# 918   http://en.wikipedia.org/wiki/2014_Abu_Dhabi_Gr...
# 582   http://en.wikipedia.org/wiki/1975_Swedish_Gran...
# 1002  https://en.wikipedia.org/wiki/2018_Italian_Gra...

# %%
show(f1.results)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24620 entries, 1 to 24625
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fastlap      24620 non-null  int64
#  1   fastlap_kph  6222 non-null   float64
#  2   fastlap_sec  6222 non-null   float64
#  3   grid         24620 non-null  int64
#  4   id_driver    24620 non-null  int64
#  5   id_race      24620 non-null  int64
#  6   id_status    24620 non-null  int64
#  7   id_team      24620 non-null  int64
#  8   laps         24620 non-null  int64
#  9   number       24620 non-null  int64
#  10  order        24620 non-null  int64
#  11  points       24620 non-null  float64
#  12  pos          24620 non-null  int64
#  13  rank         24620 non-null  int64
#  14  sec          6400 non-null   float64
# dtypes: float64(4), int64(11)
# memory usage: 3.0 MB
# None
#        fastlap  fastlap_kph  fastlap_sec  grid  id_driver  id_race  id_status  \
# 12624        0          NaN          NaN    21        173      521         12
# 12498        0          NaN          NaN    22        173      516          5
# 9646         0          NaN          NaN     4         77      413         12
# 6160         0          NaN          NaN    22        123      294         13
# 896         39      152.602       78.793    19         11       59         10
#
#        id_team  laps  number  order  points  pos  rank  sec
# 12624       58    43      18     11     0.0   11     0  NaN
# 12498       58    52      18     18     0.0    0     0  NaN
# 9646        22    42      20     10     0.0   10     0  NaN
# 6160        27    75      25     12     0.0   12     0  NaN
# 896          8    46      22     22     0.0    0    21  NaN

# %%
show(f1.teams)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209 entries, 1 to 211
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nation  209 non-null    object
#  1   ref     209 non-null    object
#  2   team    209 non-null    object
#  3   url     209 non-null    object
# dtypes: object(4)
# memory usage: 8.2+ KB
# None
#        nation      ref     team  \
# 4      French  renault  Renault
# 47    Italian     life     Life
# 108  American  epperly  Epperly
# 70      Dutch     boro     Boro
# 77    British   trojan   Trojan
#
#                                                    url
# 4    http://en.wikipedia.org/wiki/Renault_in_Formul...
# 47     http://en.wikipedia.org/wiki/Life_(Racing_Team)
# 108               http://en.wikipedia.org/wiki/Epperly
# 70     http://en.wikipedia.org/wiki/Boro_(Formula_One)
# 77   http://en.wikipedia.org/wiki/Trojan_(Racing_team)

# %%
show(f1.team_results)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11560 entries, 1 to 16059
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dsq      11560 non-null  bool
#  1   id_race  11560 non-null  int64
#  2   id_team  11560 non-null  int64
#  3   points   11560 non-null  float64
# dtypes: bool(1), float64(1), int64(2)
# memory usage: 372.5 KB
# None
#          dsq  id_race  id_team  points
# 4841   False      404       18     0.0
# 3972   False       15        5     0.0
# 4381   False      376       42     0.0
# 15364  False      962        6    22.0
# 1272   False      140        3     3.0

# %%
show(f1.team_standings)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12316 entries, 1 to 27462
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_race  12316 non-null  int64
#  1   id_team  12316 non-null  int64
#  2   points   12316 non-null  float64
#  3   pos      12316 non-null  int64
#  4   wins     12316 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 577.3 KB
# None
#        id_race  id_team  points  pos  wins
# 23628      537       21     8.0    9     0
# 9354       383       22    23.0    3     0
# 24014      514       59     0.0   10     0
# 9714       406       22     8.0    4     0
# 21601      649      198     0.0    9     0
