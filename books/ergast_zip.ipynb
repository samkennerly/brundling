# %% [markdown]
# # ErgastZIP
#
# Extract, transform, and load from an
# https://ergast.com/mrd/db database image.

# %%
# %autosave 0
from tools import ERGAST_ZIP, ErgastZIP, afew
# Out:
# Autosave disabled

# %%
f1 = ErgastZIP(ERGAST_ZIP)
f1.tables
# Out:
# ['circuits.csv',
#  'constructor_results.csv',
#  'constructors.csv',
#  'constructor_standings.csv',
#  'driver.csv',
#  'driver_standings.csv',
#  'lap_times.csv',
#  'pit_stops.csv',
#  'qualifying.csv',
#  'races.csv',
#  'results.csv',
#  'seasons.csv',
#  'status.csv']

# %% [markdown]
# ## Series

# %%
f1.seasons.head()
# Out:
# 0    2009
# 1    2008
# 2    2007
# 3    2006
# 4    2005
# Name: year, dtype: int64

# %%
f1.status.head()
# Out:
# 1        Finished
# 2    Disqualified
# 3        Accident
# 4       Collision
# 5          Engine
# Name: status, dtype: object

# %% [markdown]
# ## DataFrames

# %%
def show(data):
    print(data.info())
    return afew(data)

# %%
show(f1.circuits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 1 to 74
# Data columns (total 7 columns):
# circuit      74 non-null object
# city         74 non-null object
# country      74 non-null object
# latitude     74 non-null float64
# longitude    74 non-null float64
# ref          74 non-null object
# url          74 non-null object
# dtypes: float64(2), object(5)
# memory usage: 4.6+ KB
# None
#                           circuit          city    country  latitude  \
# 70                  Red Bull Ring     Spielburg    Austria   47.2197
# 25  Autódromo Juan y Oscar Gálvez  Buenos Aires  Argentina  -34.6943
# 20                    Nürburgring       Nürburg    Germany   50.3356
# 22                 Suzuka Circuit        Suzuka      Japan   34.8431
# 18     Autódromo José Carlos Pace     São Paulo     Brazil  -23.7036
#
#     longitude            ref  \
# 70    14.7647  red_bull_ring
# 25   -58.4593         galvez
# 20     6.9475    nurburgring
# 22   136.5410         suzuka
# 18   -46.6997     interlagos
#
#                                                   url
# 70         http://en.wikipedia.org/wiki/Red_Bull_Ring
# 25  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Os...
# 20      http://en.wikipedia.org/wiki/N%C3%BCrburgring
# 22        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 18  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...

# %%
show(f1.drivers)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 847 entries, 1 to 848
# Data columns (total 7 columns):
# birthday    847 non-null datetime64[ns]
# code        90 non-null object
# driver      847 non-null object
# nation      847 non-null object
# number      847 non-null int64
# ref         847 non-null object
# url         846 non-null object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 52.9+ KB
# None
#       birthday code              driver    nation  number                 ref  \
# 231 1947-08-29  NaN          James Hunt   British       0                hunt
# 385 1935-12-21  NaN     Lorenzo Bandini   Italian       0             bandini
# 30  1969-01-03  MSC  Michael Schumacher    German       0  michael_schumacher
# 182 1949-02-22  NaN          Niki Lauda  Austrian       0               lauda
# 541 1923-06-16  NaN       Ron Flockhart   British       0           flockhart
#
#                                                    url
# 231            http://en.wikipedia.org/wiki/James_Hunt
# 385       http://en.wikipedia.org/wiki/Lorenzo_Bandini
# 30     http://en.wikipedia.org/wiki/Michael_Schumacher
# 182            http://en.wikipedia.org/wiki/Niki_Lauda
# 541  http://en.wikipedia.org/wiki/Ron_Flockhart_(au...

# %%
show(f1.driver_standings)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32566 entries, 1 to 69748
# Data columns (total 5 columns):
# id_driver    32566 non-null int64
# id_race      32566 non-null int64
# points       32566 non-null float64
# pos          32566 non-null int64
# wins         32566 non-null int64
# dtypes: float64(1), int64(4)
# memory usage: 1.5 MB
# None
#        id_driver  id_race  points  pos  wins
# 55542        235      597     4.0   14     0
# 43310        797      835     0.0   41     0
# 56112        289      581     0.0   22     0
# 59308        211      509     0.0   25     0
# 66852         13      910    40.0    9     0

# %%
show(f1.lap_times)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472504 entries, 0 to 472503
# Data columns (total 5 columns):
# id_driver    472504 non-null int64
# id_race      472504 non-null int64
# lap          472504 non-null int64
# pos          472504 non-null int64
# seconds      472504 non-null float64
# dtypes: float64(1), int64(4)
# memory usage: 18.0 MB
# None
#         id_driver  id_race  lap  pos  seconds
# 143548         55      222   52    6  100.815
# 164716         49      178    6    6   85.777
# 32276          30      866   33   12   79.301
# 94065         828      928   53   10  133.187
# 109168        834      943   35   18   87.026

# %%
show(f1.pit_stops)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7436 entries, 0 to 7435
# Data columns (total 6 columns):
# duration     7436 non-null float64
# id_driver    7436 non-null int64
# id_race      7436 non-null int64
# lap          7436 non-null int64
# stop         7436 non-null int64
# time         7436 non-null timedelta64[ns]
# dtypes: float64(1), int64(4), timedelta64[ns](1)
# memory usage: 348.7 KB
# None
#       duration  id_driver  id_race  lap  stop     time
# 5762    26.057         18      974   39     2 14:54:53
# 5398    23.683          4      965   11     1 14:23:10
# 4401    27.286         18      942   17     1 14:38:36
# 7407    23.471        154     1029   65     2 15:36:48
# 1708    22.152        807      871   13     1 14:33:14

# %%
show(f1.qualifying)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8354 entries, 1 to 8377
# Data columns (total 8 columns):
# id_driver    8354 non-null int64
# id_race      8354 non-null int64
# id_team      8354 non-null int64
# number       8354 non-null int64
# pos          8354 non-null int64
# q1           8220 non-null float64
# q2           4260 non-null float64
# q3           2584 non-null float64
# dtypes: float64(3), int64(5)
# memory usage: 587.4 KB
# None
#       id_driver  id_race  id_team  number  pos      q1      q2      q3
# 5318         10      874      206      24   20  95.213     NaN     NaN
# 5926         20      853        9       1    1  84.002  82.914  82.275
# 8116        847     1017        3      63   19  92.789     NaN     NaN
# 2644        101      258       31      31   25  74.748     NaN     NaN
# 2287         84      244       27      26    8  84.447     NaN     NaN

# %%
show(f1.races)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1040 entries, 1 to 1052
# Data columns (total 7 columns):
# date          1040 non-null datetime64[ns]
# id_circuit    1040 non-null int64
# race          1040 non-null object
# round         1040 non-null int64
# season        1040 non-null int64
# time          308 non-null timedelta64[ns]
# url           1040 non-null object
# dtypes: datetime64[ns](1), int64(3), object(2), timedelta64[ns](1)
# memory usage: 65.0+ KB
# None
#            date  id_circuit                      race  round  season     time  \
# 621  1972-03-04          30  South African Grand Prix      2    1972      NaT
# 45   2007-07-22          20       European Grand Prix     10    2007 12:00:00
# 342  2010-05-16           6         Monaco Grand Prix      6    2010 12:00:00
# 330  1990-08-12          11      Hungarian Grand Prix     10    1990      NaT
# 1036 2020-05-10           4        Spanish Grand Prix      6    2020 13:10:00
#
#                                                     url
# 621   http://en.wikipedia.org/wiki/1972_South_Africa...
# 45    http://en.wikipedia.org/wiki/2007_European_Gra...
# 342   http://en.wikipedia.org/wiki/2010_Monaco_Grand...
# 330   http://en.wikipedia.org/wiki/1990_Hungarian_Gr...
# 1036  https://en.wikipedia.org/wiki/2020_Spanish_Gra...

# %%
show(f1.results)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24620 entries, 1 to 24625
# Data columns (total 15 columns):
# fastlap        24620 non-null int64
# fastlap_kph    6222 non-null float64
# fastlap_sec    6222 non-null float64
# grid           24620 non-null int64
# id_driver      24620 non-null int64
# id_race        24620 non-null int64
# id_status      24620 non-null int64
# id_team        24620 non-null int64
# laps           24620 non-null int64
# number         24620 non-null int64
# order          24620 non-null int64
# points         24620 non-null float64
# pos            24620 non-null int64
# rank           24620 non-null int64
# sec            6400 non-null float64
# dtypes: float64(4), int64(11)
# memory usage: 3.0 MB
# None
#        fastlap  fastlap_kph  fastlap_sec  grid  id_driver  id_race  id_status  \
# 13743        0          NaN          NaN     1        231      560          3
# 4676         0          NaN          NaN     1         71      237         20
# 9911         0          NaN          NaN    20        170      423        101
# 18154        0          NaN          NaN     8        502      749          7
# 3722         0          NaN          NaN     1         14      194          1
#
#        id_team  laps  number  order  points  pos  rank     sec
# 13743        1    32      11     16     0.0    0     0     NaN
# 4676         3     5       5     16     0.0    0     0     NaN
# 9911        53    16      19     15     0.0    0     0     NaN
# 18154       32    57       5      9     0.0    0     0     NaN
# 3722         1    62       7      1    10.0    1     0  5665.4

# %%
show(f1.teams)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209 entries, 1 to 211
# Data columns (total 4 columns):
# nation    209 non-null object
# ref       209 non-null object
# team      209 non-null object
# url       209 non-null object
# dtypes: object(4)
# memory usage: 8.2+ KB
# None
#        nation         ref        team  \
# 5     Italian  toro_rosso  Toro Rosso
# 98   Canadian      stebro      Stebro
# 109  American    phillips    Phillips
# 102   British    ferguson    Ferguson
# 111  American      trevis      Trevis
#
#                                                    url
# 5     http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# 98                 http://en.wikipedia.org/wiki/Stebro
# 109  http://en.wikipedia.org/wiki/Phillips_(constru...
# 102  http://en.wikipedia.org/wiki/Ferguson_Research...
# 111                http://en.wikipedia.org/wiki/Trevis

# %%
show(f1.team_results)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11560 entries, 1 to 16059
# Data columns (total 4 columns):
# dsq        11560 non-null bool
# id_race    11560 non-null int64
# id_team    11560 non-null int64
# points     11560 non-null float64
# dtypes: bool(1), float64(1), int64(2)
# memory usage: 372.5 KB
# None
#          dsq  id_race  id_team  points
# 14012  False      346       15     8.0
# 6147   False      492        4     6.0
# 14858  False      904       10     3.0
# 10041  False      751      118     0.0
# 9911   False      759        6     8.0

# %%
show(f1.team_standings)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12316 entries, 1 to 27462
# Data columns (total 5 columns):
# id_race    12316 non-null int64
# id_team    12316 non-null int64
# points     12316 non-null float64
# pos        12316 non-null int64
# wins       12316 non-null int64
# dtypes: float64(1), int64(4)
# memory usage: 577.3 KB
# None
#        id_race  id_team  points  pos  wins
# 26935      989        9    20.0    3     0
# 23420      559       27    18.0    8     1
# 26015      907      206     2.0    9     0
# 682         83        6    86.0    3     1
# 2217       206       17    34.0    4     1
